# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data_path = "/Users/prateekrao/Prateek/Repos/TradeModelling/dataset/tradhist.csv"

# %%
data = pd.read_csv(data_path)
# Out:
# /var/folders/qc/xp9q1kcj79315fgc2jdgwtv00000gn/T/ipykernel_63586/1675668717.py:1: DtypeWarning: Columns (8,12,14,21,24,28,33,45,46,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#    Unnamed: 0 iso_o iso_d  year  FLOW  FLOW_0 SOURCE_TF  GDP_o SOURCE_GDP_o  \
# 0           0   NaN  ADEN  1950   NaN     NaN       NaN    NaN          NaN
# 1           1   NaN  ADEN  1951   NaN     NaN       NaN    NaN          NaN
# 2           2   NaN  ADEN  1952   NaN     NaN       NaN    NaN          NaN
# 3           3   NaN  ADEN  1953   NaN     NaN       NaN    NaN          NaN
# 4           4   NaN  ADEN  1954   NaN     NaN       NaN    NaN          NaN
#
#    GDP_d  ... CONTI_o  CONTI_d REGIO_o  REGIO_d OECD_o  OECD_d EU_o  EU_d  \
# 0    NaN  ...     NaN     ASIA     NaN   MIDEST    NaN     NaN  NaN   NaN
# 1    NaN  ...     NaN     ASIA     NaN   MIDEST    NaN     NaN  NaN   NaN
# 2    NaN  ...     NaN     ASIA     NaN   MIDEST    NaN     NaN  NaN   NaN
# 3    NaN  ...     NaN     ASIA     NaN   MIDEST    NaN     NaN  NaN   NaN
# 4    NaN  ...     NaN     ASIA     NaN   MIDEST    NaN     NaN  NaN   NaN
#
#   GATT_o  GATT_d
# 0    NaN     NaN
# 1    NaN     NaN
# ...

# %%
data.shape
# Out:
# (2502427, 64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2502427 entries, 0 to 2502426
# Data columns (total 64 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   iso_o             object
#  2   iso_d             object
#  3   year              int64
#  4   FLOW              float64
#  5   FLOW_0            float64
#  6   SOURCE_TF         object
#  7   GDP_o             float64
#  8   SOURCE_GDP_o      object
#  9   GDP_d             float64
#  10  SOURCE_GDP_d      object
#  11  SH_PRIM_o         float64
#  12  SOURCE_SH_PRIM_o  object
#  13  SH_SECD_o         float64
#  14  SOURCE_SH_SECD_o  object
#  15  SH_PRIM_d         float64
#  16  SOURCE_SH_PRIM_d  object
#  17  SH_SECD_d         float64
#  18  SOURCE_SH_SECD_d  object
#  19  POP_o             float64
#  20  POP_d             float64
#  21  SOURCE_POP_o      object
#  22  SOURCE_POP_d      object
#  23  IPTOT_o           float64
#  24  SOURCE_IPTOT_o    object
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'iso_o', 'iso_d', 'year', 'FLOW', 'FLOW_0', 'SOURCE_TF',
#        'GDP_o', 'SOURCE_GDP_o', 'GDP_d', 'SOURCE_GDP_d', 'SH_PRIM_o',
#        'SOURCE_SH_PRIM_o', 'SH_SECD_o', 'SOURCE_SH_SECD_o', 'SH_PRIM_d',
#        'SOURCE_SH_PRIM_d', 'SH_SECD_d', 'SOURCE_SH_SECD_d', 'POP_o', 'POP_d',
#        'SOURCE_POP_o', 'SOURCE_POP_d', 'IPTOT_o', 'SOURCE_IPTOT_o', 'IPTOT_d',
#        'SOURCE_IPTOT_d', 'XPTOT_o', 'SOURCE_XPTOT_o', 'XPTOT_d',
#        'SOURCE_XPTOT_d', 'BITARIFF', 'TARIFF_o', 'SOURCE_TARIFF_o', 'TARIFF_d',
#        'SOURCE_TARIFF_d', 'Distw', 'Dist_coord', 'Dist_o', 'Dist_d',
#        'SeaDist_SHRT', 'SeaDist_2CST', 'Comlang', 'Contig', 'Curcol', 'Metro',
#        'Colo', 'Curcol_o', 'Curcol_d', 'Evercol', 'XCH_RATE_o', 'SOURCE_XCH_o',
#        'XCH_RATE_d', 'SOURCE_XCH_d', 'CONTI_o', 'CONTI_d', 'REGIO_o',
#        'REGIO_d', 'OECD_o', 'OECD_d', 'EU_o', 'EU_d', 'GATT_o', 'GATT_d'],
#       dtype='object')

# %% [markdown]
# ## We intend to use these features for preliminary analysis:
#
# * GDP_o
# * GDP_d
# * Dist
# * Comlang
# * XPTOT_o
# * Contig

# %%
x = data["year"]
y1 = data[data["FLOW"] > 0]["FLOW"]
y2 = data[data["FLOW"] == 0]["FLOW"]

# %%
x.shape
# Out:
# (2502427,)

# %%
plt.scatter(x, data["FLOW"])

# %%
df = data[["GDP_o", "GDP_d", "Distw", 'XPTOT_o', "FLOW"]]

# %%
df
# Out:
#                 GDP_o         GDP_d       Distw       XPTOT_o        FLOW
# 0                 NaN           NaN         NaN           NaN         NaN
# 1                 NaN           NaN         NaN           NaN         NaN
# 2                 NaN           NaN         NaN           NaN         NaN
# 3                 NaN           NaN         NaN           NaN         NaN
# 4                 NaN           NaN         NaN           NaN         NaN
# ...               ...           ...         ...           ...         ...
# 2502422  6.097825e+09  1.311544e+10  583.795386  2.070475e+09  46558256.0
# 2502423  6.838230e+09  1.464204e+10  583.795386  2.192061e+09  55171376.0
# 2502424  7.845171e+09  1.614464e+10  583.795386  2.457760e+09  58787336.0
# 2502425  8.629172e+09  1.793963e+10  583.795386  2.243481e+09  77869780.0
# 2502426  8.627889e+09  1.649053e+10  583.795386  2.089376e+09  62405360.0
#
# [2502427 rows x 5 columns]

# %%
corr = df.corr()

# %%
sns.heatmap(corr, vmin=0, vmax=1, cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see here that our target variable "Flow" has a high positive correlation between GDP_o, GDP_d and Distw

# %%
corr
# Out:
#             GDP_o     GDP_d     Distw   XPTOT_o      FLOW
# GDP_o    1.000000  0.019926  0.016623  0.811927  0.190365
# GDP_d    0.019926  1.000000  0.014959  0.040187  0.219217
# Distw    0.016623  0.014959  1.000000 -0.002070 -0.034609
# XPTOT_o  0.811927  0.040187 -0.002070  1.000000  0.232177
# FLOW     0.190365  0.219217 -0.034609  0.232177  1.000000

# %%
corr1 = data[["GDP_o", "GDP_d", "Distw", "XPTOT_o", "Contig", "Comlang", "FLOW"]].corr()

# %%
corr1
# Out:
#             GDP_o     GDP_d     Distw   XPTOT_o    Contig   Comlang      FLOW
# GDP_o    1.000000  0.019926  0.016623  0.811927  0.002132  0.013087  0.190365
# GDP_d    0.019926  1.000000  0.014959  0.040187  0.002822  0.012615  0.219217
# Distw    0.016623  0.014959  1.000000 -0.002070 -0.205606 -0.066686 -0.034609
# XPTOT_o  0.811927  0.040187 -0.002070  1.000000  0.007648 -0.015303  0.232177
# Contig   0.002132  0.002822 -0.205606  0.007648  1.000000  0.103934  0.083693
# Comlang  0.013087  0.012615 -0.066686 -0.015303  0.103934  1.000000  0.014081
# FLOW     0.190365  0.219217 -0.034609  0.232177  0.083693  0.014081  1.000000

# %%
sns.heatmap(corr1, cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can observe that there is a strong positive linear correlation between GDP_o, GDP_d, and XPTOT_o with respect to our target variable "FLOW"

# %%
plt.scatter(data["GDP_o"], data["FLOW"])

# %%
sns.heatmap(data.corr(), cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#               Unnamed: 0      year      FLOW  FLOW_0     GDP_o     GDP_d  \
# Unnamed: 0      1.000000  0.034736 -0.003452     NaN  0.035564 -0.000102
# year            0.034736  1.000000  0.048982     NaN  0.127343  0.129608
# FLOW           -0.003452  0.048982  1.000000     NaN  0.190365  0.219217
# FLOW_0               NaN       NaN       NaN     NaN       NaN       NaN
# GDP_o           0.035564  0.127343  0.190365     NaN  1.000000  0.019926
# GDP_d          -0.000102  0.129608  0.219217     NaN  0.019926  1.000000
# SH_PRIM_o       0.037751 -0.351141 -0.060164     NaN -0.176697 -0.042800
# SH_SECD_o      -0.046018 -0.063986  0.016707     NaN  0.012373 -0.005850
# SH_PRIM_d       0.000264 -0.347305 -0.060228     NaN -0.042962 -0.178701
# SH_SECD_d      -0.000345 -0.057183  0.000967     NaN -0.007097  0.009740
# POP_o          -0.050548 -0.000611  0.087793     NaN  0.306033  0.004965
# POP_d           0.000720  0.003987  0.073703     NaN  0.004137  0.302880
# ...

# %%
corr_data = data[["GDP_o", "GDP_d", "XPTOT_o", "TARIFF_o", "SeaDist_SHRT", "Comlang", "Contig", "XCH_RATE_o", "FLOW"]]

# %%
corr_data.corr()
# Out:
#                  GDP_o     GDP_d   XPTOT_o  TARIFF_o  SeaDist_SHRT   Comlang  \
# GDP_o         1.000000  0.019926  0.811927 -0.210382      0.001771  0.013087
# GDP_d         0.019926  1.000000  0.040187 -0.093239      0.000179  0.012615
# XPTOT_o       0.811927  0.040187  1.000000 -0.303683      0.012250 -0.015303
# TARIFF_o     -0.210382 -0.093239 -0.303683  1.000000     -0.037971  0.114087
# SeaDist_SHRT  0.001771  0.000179  0.012250 -0.037971      1.000000 -0.117707
# Comlang       0.013087  0.012615 -0.015303  0.114087     -0.117707  1.000000
# Contig        0.002132  0.002822  0.007648  0.077723     -0.211355  0.103934
# XCH_RATE_o   -0.006513 -0.004063 -0.008248  0.006376      0.009420 -0.002552
# FLOW          0.190365  0.219217  0.232177 -0.074790     -0.041119  0.014081
#
#                 Contig  XCH_RATE_o      FLOW
# GDP_o         0.002132   -0.006513  0.190365
# GDP_d         0.002822   -0.004063  0.219217
# XPTOT_o       0.007648   -0.008248  0.232177
# ...

# %%
sns.heatmap(corr_data.corr(), cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see from the correlation matrix:
#
# * GDP_o, GDP_d and XPTOT_o have a relatively strong relationship with FLOW
# * There is a slightly positive correlation between common language spoken and if the countries are contigious.

# %% [markdown]
# # Number of trade observations for flow

# %%
x = data["year"]

# %%
x
# Out:
# 0          1950
# 1          1951
# 2          1952
# 3          1953
# 4          1954
#            ...
# 2502422    2010
# 2502423    2011
# 2502424    2012
# 2502425    2013
# 2502426    2014
# Name: year, Length: 2502427, dtype: int64

# %%
xdata.plot.area()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 data.plot.area()
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/pandas/plotting/_core.py:1529, in PlotAccessor.area(self, x, y, **kwargs)
#    1458 def area(self, x=None, y=None, **kwargs):
#    1459     """
#    1460     Draw a stacked area plot.
#    1461
#    (...)
#    1527         >>> ax = df.plot.area(x='day')
#    1528     """
# -> 1529     return self(kind="area", x=x, y=y, **kwargs)
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
df = data[["year", "FLOW", "FLOW_0"]]

# %%
df
# Out:
#          year        FLOW  FLOW_0
# 0        1950         NaN     NaN
# 1        1951         NaN     NaN
# 2        1952         NaN     NaN
# 3        1953         NaN     NaN
# 4        1954         NaN     NaN
# ...       ...         ...     ...
# 2502422  2010  46558256.0     NaN
# 2502423  2011  55171376.0     NaN
# 2502424  2012  58787336.0     NaN
# 2502425  2013  77869780.0     NaN
# 2502426  2014  62405360.0     NaN
#
# [2502427 rows x 3 columns]

# %%
plt.plot(data.year, data["FLOW"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 plt.plot(data.year, np.count_nonzero(data["FLOW"]))
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
# ...

# %%
years = data.year

# %%
years = years.unique()

# %%
years
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 2010, 2011, 2012, 2013, 1993, 1994, 1995, 1996,
#        1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007,
#        2008, 2009, 2014, 1852, 1859, 1860, 1857, 1858, 1861, 1862, 1851,
#        1853, 1854, 1855, 1856, 1827, 1828, 1829, 1830, 1892, 1893, 1894,
#        1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905,
#        1906, 1907, 1908, 1909, 1911, 1915, 1916, 1917, 1918, 1931, 1932,
#        1832, 1833, 1834, 1835, 1836, 1837, 1838, 1839, 1840, 1841, 1842,
#        1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1863, 1864, 1865,
#        1866, 1867, 1868, 1869, 1870, 1871, 1872, 1873, 1874, 1875, 1876,
#        1877, 1878, 1879, 1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887,
# ...

# %%
len(years)
# Out:
# 188

# %%
years.sort()

# %%
years
# Out:
# array([1827, 1828, 1829, 1830, 1831, 1832, 1833, 1834, 1835, 1836, 1837,
#        1838, 1839, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848,
#        1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859,
#        1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870,
#        1871, 1872, 1873, 1874, 1875, 1876, 1877, 1878, 1879, 1880, 1881,
#        1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890, 1891, 1892,
#        1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903,
#        1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914,
#        1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925,
#        1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936,
#        1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947,
#        1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958,
#        1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
# ...

# %%
data["FLOW"] > 0
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2502422     True
# 2502423     True
# 2502424     True
# 2502425     True
# 2502426     True
# Name: FLOW, Length: 2502427, dtype: bool

# %%
df = data.groupby(["year"]).count()

# %%
data.isna().sum()[df.isna().sum()>0].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [85], in <cell line: 1>()
# ----> 1 data.isna().sum()[df.isna().sum()>0].plot(kind='bar')
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/pandas/core/series.py:980, in Series.__getitem__(self, key)
#     977     key = list(key)
#     979 if com.is_bool_indexer(key):
# --> 980     key = check_bool_indexer(self.index, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
#
# File ~/miniforge3/envs/mlb/lib/python3.8/site-packages/pandas/core/indexing.py:2383, in check_bool_indexer(index, key)
#    2381     mask = isna(result._values)
#    2382     if mask.any():
# -> 2383         raise IndexingError(
#    2384             "Unalignable boolean Series provided as "
#    2385             "indexer (index of the boolean Series and of "
# ...

# %%
df
# Out:
#       Unnamed: 0  iso_o  iso_d   FLOW  FLOW_0  SOURCE_TF  GDP_o  SOURCE_GDP_o  \
# year
# 1827         234    225    225    150      66        150    131           131
# 1828         248    241    241    166      68        166    135           135
# 1829         225    216    216    143      64        143    126           126
# 1830         249    241    241    165      68        165    136           136
# 1831         365    360    360    204     151        204    228           228
# ...          ...    ...    ...    ...     ...        ...    ...           ...
# 2010       37009  36990  36990  32172    4799      32172  34579         34579
# 2011       37122  37102  37102  32172    4910      32172  34680         34680
# 2012       36937  36919  36919  32172    4729      32172  34332         34332
# 2013       36983  36966  36966  32172    4777      32172  34555         34555
# 2014       36999  36985  36985  32172    4799      32172  33450         33450
#
# ...

# %%
first_col = df["FLOW"]

# %%
plt.stackplot(years, df["FLOW"])

# %%
df2 = data.groupby(["year"].count()
# Out:
#   Input In [117]
#     df2 = data.groupby(["year"].count()
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
df2["FLOW_0"]
# Out:
# year
# 1827      66
# 1828      68
# 1829      64
# 1830      68
# 1831     151
#         ...
# 2010    4799
# 2011    4910
# 2012    4729
# 2013    4777
# 2014    4799
# Name: FLOW_0, Length: 188, dtype: int64

# %%
plt.xlabel("Year")
plt.ylabel("")

plt.stackplot(years, np.log(first_col), np.log(df["FLOW_0"]))

# %%
import matplotlib.pyplot as plt
def plot_nas(df: pd.DataFrame):
    if df.isnull().sum().sum() != 0:
        na_df = (df.isnull().sum() / len(df)) * 100
        na_df = na_df.drop(na_df[na_df == 0].index).sort_values(ascending=False)
        missing_data = pd.DataFrame({'Missing Ratio %' :na_df})
        missing_data.plot(kind = "barh")
        plt.xlabel("Number of missing values")
        plt.ylabel("Features")
        plt.title("Null value analysis")
        plt.show()
    else:
        print('No NAs found')

data1 = data[["GDP_o", "GDP_d", "XPTOT_o", "TARIFF_o", "SeaDist_SHRT", "Comlang", "Contig", "XCH_RATE_o", "FLOW"]]

plot_nas(data1)
